# %% [markdown]
# # **TikTok Project**
# **Course 3 - Go Beyond the Numbers: Translate Data into Insights**

# %% [markdown]
# **Exploratory data analysis for Tiktok Claims Classification model**
#
# Project Objective: The aim of the Tiktok project is to develop a machine learning model that is capable of categorizing videos as either an opinion or a claim. This model, when completed will help reduce the backlog of unclassified videos and allow for the team to focus on other productive tasks.
#
# In this part, we will examine data provided and prepare it for analysis.
#
# **The purpose** of this project is to conduct exploratory data analysis on the Tiktok data set. WE PLAN TO INVESTIGATE what distinguishes claim videos from opinion videos.
#
# **The goal** is to explore the dataset and create visualizations.
# <br/>
# *This activity has 4 parts:*
#
# **Part 1:** Imports, links, and loading
#
# **Part 2:** Data Exploration
# *   Data cleaning
#
#
# **Part 3:** Build visualizations
#
# **Part 4:** Evaluate and share results

# %% [markdown]
# # **Visualize a story in Tableau and Python**

# %% [markdown]
# <img src="images/Plan.png" width="100" height="100" align=left>
#
#
# ## **PACE: Plan**
#
# In the Plan stage of the PACE frmework, our goal is to identify our requirements for the project athand. ice our goal is to carry out Exploratory data analysis(EDA), our plan involves identifying our data types, using boxplots to determine if any outliers are present and making plans to handle them.

# %% [markdown]
# ### **Task 1. Imports, links, and loading**

# %%
# Import packages for data manipulation
import pandas as pd
import numpy as np
# Import packages for data visualization
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# Load dataset into dataframe
data = pd.read_csv("tiktok_dataset.csv")

# %% [markdown]
# <img src="images/Analyze.png" width="100" height="100" align=left>
#
# ## **PACE: Analyze**

# %% [markdown]
# ### **Data exploration and cleaning**
#
# We will first explore our data to get an understanding of it's properties and structure. Also we want to understand if outliers and missing data are present in the dataset. and make a decision on how to handle them if any. The functions listed below wiill help us to have an understanding of what the data is all about.
#
# *    `.head()`
# *    `.info()`
# *    `.describe()`
# *    `.groupby()`
# *    `.sort_values()`

# %%
# Display and examine the first few rows of the dataframe

data.head()
# Out:
#    # claim_status    video_id  video_duration_sec  \
# 0  1        claim  7017666017                  59
# 1  2        claim  4014381136                  32
# 2  3        claim  9859838091                  31
# 3  4        claim  1866847991                  25
# 4  5        claim  7105231098                  19
#
#                             video_transcription_text verified_status  \
# 0  someone shared with me that drone deliveries a...    not verified
# 1  someone shared with me that there are more mic...    not verified
# 2  someone shared with me that american industria...    not verified
# 3  someone shared with me that the metro of st. p...    not verified
# 4  someone shared with me that the number of busi...    not verified
#
#   author_ban_status  video_view_count  video_like_count  video_share_count  \
# 0      under review          343296.0           19425.0              241.0
# 1            active          140877.0           77355.0            19034.0
# ...

# %%
# Get the size of the data

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19382 entries, 0 to 19381
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   #                         19382 non-null  int64
#  1   claim_status              19084 non-null  object
#  2   video_id                  19382 non-null  int64
#  3   video_duration_sec        19382 non-null  int64
#  4   video_transcription_text  19084 non-null  object
#  5   verified_status           19382 non-null  object
#  6   author_ban_status         19382 non-null  object
#  7   video_view_count          19084 non-null  float64
#  8   video_like_count          19084 non-null  float64
#  9   video_share_count         19084 non-null  float64
#  10  video_download_count      19084 non-null  float64
#  11  video_comment_count       19084 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 1.8+ MB

# %%
# Get the shape of the data

data.shape
# Out:
# (19382, 12)

# %% [markdown]
# we can see that the dataset has 19382 rows and 12 columns

# %%
# Get basic information about the data

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19382 entries, 0 to 19381
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   #                         19382 non-null  int64
#  1   claim_status              19084 non-null  object
#  2   video_id                  19382 non-null  int64
#  3   video_duration_sec        19382 non-null  int64
#  4   video_transcription_text  19084 non-null  object
#  5   verified_status           19382 non-null  object
#  6   author_ban_status         19382 non-null  object
#  7   video_view_count          19084 non-null  float64
#  8   video_like_count          19084 non-null  float64
#  9   video_share_count         19084 non-null  float64
#  10  video_download_count      19084 non-null  float64
#  11  video_comment_count       19084 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 1.8+ MB

# %%
# Generate a table of descriptive statistics

data.describe()
# Out:
#                   #      video_id  video_duration_sec  video_view_count  \
# count  19382.000000  1.938200e+04        19382.000000      19084.000000
# mean    9691.500000  5.627454e+09           32.421732     254708.558688
# std     5595.245794  2.536440e+09           16.229967     322893.280814
# min        1.000000  1.234959e+09            5.000000         20.000000
# 25%     4846.250000  3.430417e+09           18.000000       4942.500000
# 50%     9691.500000  5.618664e+09           32.000000       9954.500000
# 75%    14536.750000  7.843960e+09           47.000000     504327.000000
# max    19382.000000  9.999873e+09           60.000000     999817.000000
#
#        video_like_count  video_share_count  video_download_count  \
# count      19084.000000       19084.000000          19084.000000
# mean       84304.636030       16735.248323           1049.429627
# std       133420.546814       32036.174350           2004.299894
# ...

# %% [markdown]
# <img src="images/Construct.png" width="100" height="100" align=left>
#
# ## **PACE: Construct**
#
# Continuing with the pace framework, we now move on to the construct stage. in this stage we visualize our data,check for outliers and handle them, and handle missing data.

# %% [markdown]
# ### Build visualizations

# %% [markdown]
# #### **video_duration_sec**
#
#  Let's Create a box plot to examine the spread of values in the `video_duration_sec` column.

# %%
# Create a boxplot to visualize distribution of `video_duration_sec`

sns.boxplot(x=data['video_duration_sec'])
plt.title('Boxplot of Video Duration (Seconds)')
plt.xlabel('Video Duration (Seconds)')
plt.show()

# %% [markdown]
# The "video_duration_sec" column is fairly balanced with the mean around 31 seconds

# %% [markdown]
# Next let's Create a histogram of the values in the `video_duration_sec` column to further explore the distribution of this variable.

# %%
# Create a histogram

sns.histplot(data['video_duration_sec'], bins=10, kde=True)

# Add title and labels
plt.title('Distribution of Video Duration (Seconds)')
plt.xlabel('Video Duration (Seconds)')
plt.ylabel('Frequency')

# Display the plot
plt.show()

# %% [markdown]
# we can see that the videos are fairly evenly distributed

# %% [markdown]
# #### **video_view_count**
# Let us Create a box plot to examine the spread of values in the `video_view_count` column.

# %%
# Create a boxplot to visualize distribution of `video_view_count`

sns.boxplot(x=data['video_view_count'])

# Add title and labels
plt.title('Boxplot of Number of Video Views')
plt.xlabel('Number of Views')

# Display the plot
plt.show()

# %% [markdown]
# Create a histogram of the values in the `video_view_count` column to further explore the distribution of this variable.

# %%
# Create a histogram


sns.histplot(data['video_view_count'], bins=10, kde=True)

# Add title and labels
plt.title('Distribution of Video Views')
plt.xlabel('Number of Views')
plt.ylabel('Frequency')

# Display the plot
plt.show()

# %% [markdown]
# The video view column is highly skewed to the right... indicating that majority of viws lie in the 0-1M range

# %% [markdown]
# #### **video_like_count**
#
# Now, we'll Create a box plot to examine the spread of values in the `video_like_count` column.

# %%
# Create a boxplot to visualize distribution of `video_like_count`

sns.boxplot(x=data['video_like_count'])

# Add title and labels
plt.title('Boxplot of Number of Video Likes')
plt.xlabel('Number of Likes')

# Display the plot
plt.show()

# %% [markdown]
# We can see a lot of datapoints falling above the 75 Percentile of the data.

# %% [markdown]
# we will now create a histogram of the values in the `video_like_count` column to further explore the distribution of this variable.

# %%
# Create a histogram

sns.histplot(data['video_like_count'], bins=10, kde=True)

# Add title and labels
plt.title('Distribution of Video Likes')
plt.xlabel('Number of Likes')
plt.ylabel('Frequency')

# Display the plot
plt.show()

# %% [markdown]
# The distribution of the video likes is not even but skewed to the right. most of the values lies between 0 and 100,000. it also appears that there are outliers in the data

# %% [markdown]
# #### **video_comment_count**
#
# Create a box plot to examine the spread of values in the `video_comment_count` column.

# %%
# Create a boxplot to visualize distribution of `video_comment_count`

sns.boxplot(x=data['video_comment_count'])

# Add title and labels
plt.title('Boxplot of Number of Video Comments')
plt.xlabel('Number of Comments')

# Display the plot
plt.show()

# %% [markdown]
# Create a histogram of the values in the `video_comment_count` column to further explore the distribution of this variable.

# %%
# Create a histogram

sns.histplot(data['video_comment_count'], bins=10, kde=True)

# Add title and labels
plt.title('Distribution of Video Comments')
plt.xlabel('Number of Comments')
plt.ylabel('Frequency')

# Display the plot
plt.show()

# %% [markdown]
# This variable also appears t be right-skewed

# %% [markdown]
# #### **video_share_count**
#
# Create a box plot to examine the spread of values in the `video_share_count` column.

# %%
# Create a boxplot to visualize distribution of `video_share_count`

sns.boxplot(x=data['video_share_count'])

# Add title and labels
plt.title('Boxplot of Number of Video Shares')
plt.xlabel('Number of Shares')

# Display the plot
plt.show()

# %% [markdown]
# *Create* a histogram of the values in the `video_share_count` column to further explore the distribution of this variable.

# %%
# Create a histogram

sns.histplot(data['video_share_count'], bins=10, kde=True)

# Add title and labels
plt.title('Distribution of Video Shares')
plt.xlabel('Number of Shares')
plt.ylabel('Frequency')

# Display the plot
plt.show()

# %% [markdown]
# Again, we see a right-skewed distribution of the variable video_share_count

# %% [markdown]
# #### **video_download_count**
#
# Create a box plot to examine the spread of values in the `video_download_count` column.

# %%
# Create a boxplot to visualize distribution of `video_download_count`

sns.boxplot(x=data['video_download_count'])

# Add title and labels
plt.title('Boxplot of Number of Video Downloads')
plt.xlabel('Number of Downloads')

# Display the plot
plt.show()

# %% [markdown]
# Create a histogram of the values in the `video_download_count` column to further explore the distribution of this variable.

# %%
# Create a histogram

sns.histplot(data['video_download_count'], bins=10, kde=True)

# Add title and labels
plt.title('Distribution of Video Downloads')
plt.xlabel('Number of Downloads')
plt.ylabel('Frequency')

# Display the plot
plt.show()

# %% [markdown]
# For this variable, we also have a higher frequency of the number of dowbnloads in the range of 0-1000

# %% [markdown]
# #### **Claim status by verification status**
#
# Now, create a histogram with four bars: one for each combination of claim status and verification status.

# %%
# Create a count plot (which is like a histogram for categorical data)
sns.countplot(x='claim_status', hue='verified_status', data=data)

# Add title and labels
plt.title('Distribution of Claim and Verification Status')
plt.xlabel('Claim Status')
plt.ylabel('Count')

# Display the plot
plt.show()

# %% [markdown]
# From the distribution,above, we can see that there are significantly more unverified users than verified users. We can also see that verified users are more likely to post opinions than claims.

# %% [markdown]
# #### **Claim status by author ban status**
#
# Let us examine the relationship between the authors' ban status(if they are banned, active or under review) and their likelihood of either posting an opinion or a claim

# %%
# Create a histogram

sns.countplot(x='claim_status', hue='author_ban_status', data=data)

# Add title and labels
plt.title('Distribution of Claim and Ban Status')
plt.xlabel('Claim Status')
plt.ylabel('Count')

# Display the plot
plt.show()

# %% [markdown]
# the active authors are substantially more than the banned authors in both categories, and while the active users who post Opinion categorized videos are slightly more than those that post claim videos, users whose status is either banned or under review are more likely to post a claim video.

# %% [markdown]
# #### **Median view counts by ban status**
#
# Because the video views variable is highly skewed, it may be more efficient to use the median when examining the relationships with other variables. Using the mean may affect the analysis because of the big values at the right tail

# %%
# Create a bar plot

author_ban_status_median = data.loc[:,['author_ban_status','video_view_count']].groupby('author_ban_status').median().reset_index()

# %%
author_ban_status_median
# Out:
#   author_ban_status  video_view_count
# 0            active            8616.0
# 1            banned          448201.0
# 2      under review          365245.5

# %%
# Create a bar plot
sns.barplot(x='author_ban_status', y= 'video_view_count', hue='author_ban_status', data=author_ban_status_median)

# Add title and labels
plt.title('Median of Author Ban Status')
plt.xlabel('Ban Status')
plt.ylabel('Median')

# Display the plot
plt.show()

# %% [markdown]
# From the plot, we can see that authors whose status is either banned or under review have higher median video views than active authors. this may have an effect of the claim status (higher video views, and banned or under review status might indicate that the video is a claim)

# %%
# Calculate the median view count for claim status.

claim_status_median = data.loc[:,['claim_status','video_view_count']].groupby('claim_status').median().reset_index()

# %%
sns.barplot(x='claim_status', y= 'video_view_count', hue='claim_status', data=claim_status_median)

# Add title and labels
plt.title('Median of Author Claim Status Status')
plt.xlabel('Claim Status')
plt.ylabel('Median')

# Display the plot
plt.show()

# %% [markdown]
# We can once again see that there is a correlation between the number of video views and the claim_status. Claim videos have significantly higher views than opinions

# %% [markdown]
# #### **Total views by claim status**
#
# Let's represent this information on a pie chart to better visualize this.

# %%
claim_counts = data.loc[:,['video_view_count','claim_status']].groupby('claim_status').sum().reset_index()

# %%
claim_counts
# Out:
#   claim_status  video_view_count
# 0        claim      4.813891e+09
# 1      opinion      4.696715e+07

# %%
data['claim_status'].value_counts()
# Out:
# claim      9608
# opinion    9476
# Name: claim_status, dtype: int64

# %%
# Create a pie graph

# Create a pie chart
plt.figure(figsize=(8, 6))
plt.pie(claim_counts['video_view_count'], labels=claim_counts['claim_status'], autopct='%1.1f%%', startangle=0)

# Add title
plt.title('Proportion of Claim Status')

# Display the plot
plt.show()

# %% [markdown]
# it is evident that claim videos gather more videos than opinions.

# %% [markdown]
# ### **Task 4. Determine outliers**
#
# When building predictive models, the presence of outliers can be problematic. For example, if we were trying to predict the view count of a particular video, videos with extremely high view counts might introduce bias to a model. Also, some outliers might indicate problems with how data was captured or recorded.
#
# The ultimate objective of the TikTok project is to build a model that predicts whether a video is a claim or opinion. The analysis you've performed indicates that a video's engagement level is strongly correlated with its claim status. There's no reason to believe that any of the values in the TikTok data are erroneously captured, and they align with expectation of how social media works: a very small proportion of videos get super high engagement levels. That's the nature of viral content.
#
# In this TikTok dataset, the values for the count variables are not normally distributed. They are heavily skewed to the right. One way of modifying the outlier threshold is by calculating the **median** value for each variable and then adding 1.5 * IQR. This results in a threshold that is, in this case, much lower than it would be if you used the 3rd quartile.
#
# we will Write a for loop that iterates over the column names of each count variable. For each iteration we will:
# 1. Calculate the IQR of the column
# 2. Calculate the median of the column
# 3. Calculate the outlier threshold (median + 1.5 * IQR)
# 4. Calculate the numer of videos with a count in that column that exceeds the outlier threshold
# 5. Print "Number of outliers, {column name}: {outlier count}"
#
# ```
# Example:
# Number of outliers, video_view_count: ___
# Number of outliers, video_like_count: ___
# Number of outliers, video_share_count: ___
# Number of outliers, video_download_count: ___
# Number of outliers, video_comment_count: ___
# ```

# %%
def address_outliers(x):
    count_columns = ['video_view_count','video_like_count','video_share_count','video_download_count','video_comment_count']
    for column in count_columns:
        percentile25 = x[column].quantile(0.25)
        percentile75 = x[column].quantile(0.75)
        IQR = percentile75 - percentile25
        median = np.nanmedian(x[column])
        outlier_thresh = median + (1.5 * IQR)
        outlier_count = len(x[x[column] > outlier_thresh])
        print(column + " : " + "Percentile25: " + str(percentile25))
        print(column + " : " + "Percentile75: " + str(percentile75))
        print(column + " : " + "IQR: " + str(IQR))
        print(column + " : " + "median: " + str(median))
        print(column + " : " + "outlier_thresh: " + str(outlier_thresh))
        print(column + " : " + "outlier_count: " + str(outlier_count))

# %%
np.nanmedian(data['video_view_count'])

# %%
address_outliers(data)
# Out:
# video_view_count : Percentile25: 4942.5
# video_view_count : Percentile75: 504327.0
# video_view_count : IQR: 499384.5
# video_view_count : median: 9954.5
# video_view_count : outlier_thresh: 759031.25
# video_view_count : outlier_count: 2343
# video_like_count : Percentile25: 810.75
# video_like_count : Percentile75: 125020.0
# video_like_count : IQR: 124209.25
# video_like_count : median: 3403.5
# video_like_count : outlier_thresh: 189717.375
# video_like_count : outlier_count: 3468
# video_share_count : Percentile25: 115.0
# video_share_count : Percentile75: 18222.0
# video_share_count : IQR: 18107.0
# video_share_count : median: 717.0
# video_share_count : outlier_thresh: 27877.5
# video_share_count : outlier_count: 3732
# video_download_count : Percentile25: 7.0
# video_download_count : Percentile75: 1156.25
# video_download_count : IQR: 1149.25
# video_download_count : median: 46.0
# video_download_count : outlier_thresh: 1769.875
# video_download_count : outlier_count: 3733
# ...

# %% [markdown]
# #### **Scatterplot**

# %%
# Create a scatterplot of `video_view_count` versus `video_like_count` according to 'claim_status'

# Create scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x="video_view_count", y="video_like_count", hue="claim_status", palette="Set1")

# Labels and Title
plt.xlabel("Video View Count")
plt.ylabel("Video Like Count")
plt.title("Scatterplot of Video Views vs Likes by Claim Status")

# Show plot
plt.show()

# %%
opinion_data = data[data['claim_status'] == 'opinion']

# %%
data

# %%
# Create a scatterplot of ``video_view_count` versus `video_like_count` for opinions only
plt.figure(figsize=(10, 6))
sns.scatterplot(data=opinion_data, x="video_view_count", y="video_like_count", hue="claim_status", palette="Set1")

# Labels and Title
plt.xlabel("Video View Count")
plt.ylabel("Video Like Count")
plt.title("Scatterplot of Video Views vs Likes by Claim Status")

# Show plot
plt.show()

# %% [markdown]
# <img src="images/Execute.png" width="100" height="100" align=left>
#
# ## **PACE: Execute**
#
# This is the execute stage of the PACE framework. In this stage, we communicate our findings concisely.
# we have been able to establish a relationship between video engagements and the claim status. we will have to determine the statistical significance of the difference between the engagement level of claim and opinion videos
